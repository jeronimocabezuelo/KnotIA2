# %%
from copy import copy,deepcopy 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
from Path import *
from CustomKnot import *
from KnotDatabase import *
from KnotStar import *
from random import *
from KnotGA import *
from KnotAnt import *
np.set_printoptions(threshold=np.inf,linewidth=np.inf,nanstr="n")
pd.options.display.max_colwidth = 100

# %%
knot_3_1_1 = CustomKnot([X(1,4,6,3), X(2,5,3,6), X(4,1,5,2)])
knot_3_1_2 = CustomKnot([X(1,4,2,5), X(2,7,3,8), X(5,8,6,1), X(6,3,7,4)])

differences = DifferenceSimpleCache(knot_3_1_2)

# %%
print("init Difference",difference(knot_3_1_1,knot_3_1_2))

_,_,differencesMMM = areSameKnotGA(knot_3_1_1, knot_3_1_2, 
                                    numberOfIndividuals=500, 
                                    numberOfGenerations=100, 
                                    debug=1,
                                    maxMutationRateType = 0.045, 
                                    minMutationRateType = 0.001, 
                                    maxMutationRateGene = 0.09, 
                                    minMutationRateGene = 0.002, 
                                    maxMutationRateGenes = 0.14, 
                                    minMutationRateGenes = 0.006,
                                    differences = differences,
                                    generationGrowthRate=[10, 100])
plotDifferences(differencesMMM)
# Out:
# init Difference 12.5
# Generation: 1 , Pre generation Population:  500
#   maxDifference:   95.41304347826089
#   meanDifference:  30.832577492412966
#   minDifference:   6.2
# differences len:  2769 differences calls:  6858
# Generation: 1 , Post generation Population: 500
# Generation: 2 , Pre generation Population:  500
#   percentage selection calculate Difference: 17.50
#  Encontrado ['', '', '', '.createALoop(1,1)', '.reidemeisterIII(1,3,6)', '', '', '.createALoop(6,0)', '.undoALoop(1)']
# Generation: 2 , Post generation Population: 1000

# %%
#Tres proyecciones del nudo figura en 8 
k1 = CustomKnot([X(3,8,2,7),X(7,4,6,3),X(8,6,1,5),X(5,1,4,2)])
k2 = CustomKnot([X(6,8,5,1),X(7,2,8,3),X(3,6,4,7),X(2,4,1,5)])
k3 = CustomKnot([X(2,8,1,9),X(7,3,8,2),X(4,6,3,7),X(4,9,5,10),X(10,5,1,6)])

print("k1==k2",k1==k2)
print("k2==k3",k2==k3)
print("k1==k3",k1==k3)

print("same k1,k2",areSameKnotGA(k1,k2,500,debug=1))
print("same k2,k3",areSameKnotGA(k2,k3,500,debug=1))
print("same k1,k3",areSameKnotGA(k1,k3,500,debug=1))
print("same k2,k1",areSameKnotGA(k2,k1,500,debug=1))
print("same k3,k2",areSameKnotGA(k3,k2,500,debug=1))
print("same k3,k1",areSameKnotGA(k3,k1,500,debug=1))
# Out:
# k1==k2 True
# k2==k3 False
# k1==k3 False
# same k1,k2 (True, <KnotGA.IndividualKnot object at 0x13dcd7b80>)
# Generation: 1 , Pre generation Population:  500
#   percentage selection calculate Difference: 50.80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jeronimocabezueloruiz/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/NotebookGA.ipynb Celda 4 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/Users/jeronimocabezueloruiz/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/NotebookGA.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> print("k1==k3",k1==k3)
#      <a href='vscode-notebook-cell:/Users/jeronimocabezueloruiz/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/NotebookGA.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> print("same k1,k2",areSameKnotGA(k1,k2,500,debug=1))
# ---> <a href='vscode-notebook-cell:/Users/jeronimocabezueloruiz/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/NotebookGA.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> print("same k2,k3",areSameKnotGA(k2,k3,500,debug=1))
#      <a href='vscode-notebook-cell:/Users/jeronimocabezueloruiz/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/NotebookGA.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> print("same k1,k3",areSameKnotGA(k1,k3,500,debug=1))
#      <a href='vscode-notebook-cell:/Users/jeronimocabezueloruiz/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/NotebookGA.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> print("same k2,k1",areSameKnotGA(k2,k1,500,debug=1))
#
# File ~/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/KnotGA.py:386, in areSameKnotGA(knot1, knot2, numberOfIndividuals, numberOfGenerations, differences, debug, maxMutationRateType, minMutationRateType, maxMutationRateGene, minMutationRateGene, maxMutationRateGenes, minMutationRateGenes, generationGrowthRate)
#     383 if debug > 0:
#     384     print("Generation:", c, ", Pre generation Population: ",
#     385           len(population.population))
# --> 386 a = population.newGeneration(debug=debug)
#     387 if debug > 0:
#     388     print("Generation:", c, ", Post generation Population:",
#     389           len(population.population))
#
# File ~/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/KnotGA.py:348, in PopulationKnot.newGeneration(self, debug)
#     346 self.mutate(debug=debug)
#     347 self._generation += 1
# --> 348 a = self.selection(debug=debug)
#     349 self.updateMutationRates()
#     350 if a != None:
#
# File ~/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/KnotGA.py:247, in PopulationKnot.selection(self, times, debug)
#     245 if times:
#     246     print("time individual computedKnot", time()-start)
# --> 247 similar = self.differences[computedKnot]
#     248 if times:
#     249     print("time individual differences", time()-start)
#
# File ~/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/KnotStar.py:405, in DifferenceSimpleCache.__getitem__(self, knot)
#     403     return tupleDifference
#     404 else:
# --> 405     tupleDifference = difference(knot, self.objetiveKnot)
#     406     self.differences[knotReprese] = tupleDifference
#     407     if self.times:
#
# File ~/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/KnotStar.py:284, in difference(knot1, knot2)
#     282     aux = 0
#     283     for s in range(max(n1, n2)):
# --> 284         aux += differenceOfStrand(s, rotation, knot2, n1=n1, n2=n2)
#     285     auxes.append(aux)
#     286 return min(auxes)+abs(n1-n2)
#
# File ~/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/KnotStar.py:304, in differenceOfStrand(s, knot1, knot2, n1, n2)
#     302 s2 = mod(s, n2)
#     303 cross1, p1 = crossWithStrandAndDirection(knot1, s1, True)
# --> 304 cross2, p2 = crossWithStrandAndDirection(knot2, s2, True)
#     305 strandAbove1 = cross1.isStrandAbove(s1)
#     306 strandAbove2 = cross2.isStrandAbove(s2)
#
# File ~/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/CustomKnot.py:1154, in crossWithStrandAndDirection(knot, strand, direction)
#    1152 for cross in crosses:
#    1153     for i in cross.indexForStrand(strand):
# -> 1154         if cross.strands[(i+2) % 4] == mod(strand + (1 if direction else -1), knot.numberOfStrands):
#    1155             return cross, i
#
# File ~/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/CustomKnot.py:130, in CustomKnot.numberOfStrands(self)
#     127 @property
#     128 def numberOfStrands(self):
#     129     """It returns the number of strands."""
# --> 130     return len(set([strand for cross in self.crosses for strand in cross.strands]))
#
# File ~/MEGA/UNIR/TRABAJOFINMASTER/2023/KnotIA/CustomKnot.py:130, in <listcomp>(.0)
#     127 @property
#     128 def numberOfStrands(self):
#     129     """It returns the number of strands."""
# --> 130     return len(set([strand for cross in self.crosses for strand in cross.strands]))
#
# KeyboardInterrupt:

# %%
k5_1_1 = CustomKnot([ X(1,8,2,9), X(2,11,3,12), X(4,14,5,13), X(5,18,6,1), X(6,15,7,16), X(9,12,10,13), X(10,3,11,4), X(14,17,15,18), X(16,7,17,8)])
k5_1_2 = CustomKnot([ X(1,8,32,7), X(1,20,2,21), X(3,22,4,23), X(5,25,6,24), X(8,27,9,28), X(12,31,13,32), X(14,10,15,9), X(15,29,16,28), X(16,11,17,12), X(17,30,18,31), X(18,14,19,13), X(19,6,20,7), X(21,2,22,3), X(25,5,26,4), X(26,24,27,23), X(29,10,30,11)])

differences_5_1_2 = DifferenceSimpleCache(k5_1_2)

# %%
print("init Difference",difference(k5_1_1,k5_1_2))

_,_,differencesMMM = areSameKnotGA(k5_1_1, k5_1_2, 
                                   numberOfIndividuals=500, 
                                   numberOfGenerations=100, 
                                   debug=1,
                                   maxMutationRateType = 0.045, 
                                   minMutationRateType = 0.001, 
                                   maxMutationRateGene = 0.09, 
                                   minMutationRateGene = 0.002, 
                                   maxMutationRateGenes = 0.14, 
                                   minMutationRateGenes = 0.006,
                                   differences = differences_5_1_2,
                                   generationGrowthRate=[10, 100])
plotDifferences(differencesMMM)
# Out:
# init Difference 51.15625
# Generation: 1 , Pre generation Population:  500
#   maxDifference:   79.05555555555554
#   meanDifference:  41.526004075261184
#   minDifference:   28.3125
# differences len:  916 differences calls:  1000
# Generation: 1 , Post generation Population: 500
# Generation: 2 , Pre generation Population:  500
#   maxDifference:   96.8166666666667
#   meanDifference:  40.327615474283284
#   minDifference:   24.8125
# differences len:  1460 differences calls:  2000
# Generation: 2 , Post generation Population: 500
# Generation: 3 , Pre generation Population:  500
#   maxDifference:   73.57999999999998
#   meanDifference:  39.5609964467226
#   minDifference:   24.8125
# differences len:  2035 differences calls:  3000
# Generation: 3 , Post generation Population: 500
# Generation: 4 , Pre generation Population:  500
#   maxDifference:   79.2037037037037
#   meanDifference:  39.178183677640966
#   minDifference:   26.9375
# differences len:  2602 differences calls:  4000
# Generation: 4 , Post generation Population: 500
# Generation: 5 , Pre generation Population:  500
#   maxDifference:   73.66
#   meanDifference:  38.580856319263454
#   minDifference:   26.4375
# differences len:  3189 differences calls:  5000
# Generation: 5 , Post generation Population: 500
# Generation: 6 , Pre generation Population:  500
#   maxDifference:   66.97916666666669
#   meanDifference:  38.09841531337814
#   minDifference:   25.3125
# differences len:  3745 differences calls:  6000
# Generation: 6 , Post generation Population: 500
# Generation: 7 , Pre generation Population:  500
#   maxDifference:   60.88636363636364
#   meanDifference:  37.80709355962881
#   minDifference:   25.3125
# differences len:  4302 differences calls:  7000
# Generation: 7 , Post generation Population: 500
# Generation: 8 , Pre generation Population:  500
#   maxDifference:   53.16666666666666
#   meanDifference:  37.61795377966977
#   minDifference:   25.3125
# differences len:  4886 differences calls:  8000
# Generation: 8 , Post generation Population: 500
# Generation: 9 , Pre generation Population:  500
#   maxDifference:   51.15625
#   meanDifference:  37.49291455968352
#   minDifference:   25.3125
# differences len:  5483 differences calls:  9000
# Generation: 9 , Post generation Population: 500
# Generation: 10 , Pre generation Population:  500
#   maxDifference:   51.775000000000006
#   meanDifference:  37.14533880073957
#   minDifference:   24.3125
# differences len:  6047 differences calls:  10000
# Generation: 10 , Post generation Population: 600
# Generation: 11 , Pre generation Population:  600
#   maxDifference:   53.275
#   meanDifference:  37.000555211558314
#   minDifference:   26.4375
# differences len:  6738 differences calls:  11200
# Generation: 11 , Post generation Population: 600
# Generation: 12 , Pre generation Population:  600
#   maxDifference:   53.275
#   meanDifference:  36.715382666480316
#   minDifference:   24.4375
# differences len:  7420 differences calls:  12400
# Generation: 12 , Post generation Population: 600
# Generation: 13 , Pre generation Population:  600
#   maxDifference:   51.15625
#   meanDifference:  36.71349855951151
#   minDifference:   24.4375
# differences len:  8121 differences calls:  13600
# Generation: 13 , Post generation Population: 600
# Generation: 14 , Pre generation Population:  600
#   maxDifference:   51.15625
#   meanDifference:  36.805521827700375
#   minDifference:   23.0625
# differences len:  8864 differences calls:  14800
# Generation: 14 , Post generation Population: 600
# Generation: 15 , Pre generation Population:  600
#   maxDifference:   51.15625
#   meanDifference:  36.820898316563465
#   minDifference:   23.0625
# differences len:  9578 differences calls:  16000
# Generation: 15 , Post generation Population: 600
# Generation: 16 , Pre generation Population:  600
#   maxDifference:   51.15625
#   meanDifference:  36.76698118227553
#   minDifference:   23.0625
# differences len:  10300 differences calls:  17200
# Generation: 16 , Post generation Population: 600
# Generation: 17 , Pre generation Population:  600
#   maxDifference:   51.15625
#   meanDifference:  36.91932861412108
#   minDifference:   25.0625
# differences len:  10992 differences calls:  18400
# Generation: 17 , Post generation Population: 600
# Generation: 18 , Pre generation Population:  600
#   maxDifference:   51.15625
#   meanDifference:  36.84260059232026
#   minDifference:   25.0625
# differences len:  11680 differences calls:  19600
# Generation: 18 , Post generation Population: 600
# Generation: 19 , Pre generation Population:  600
#   maxDifference:   51.15625
#   meanDifference:  36.848065194645116
#   minDifference:   25.0625
# differences len:  12367 differences calls:  20800
# Generation: 19 , Post generation Population: 600
# Generation: 20 , Pre generation Population:  600
#   maxDifference:   51.15625
#   meanDifference:  36.70400968208922
#   minDifference:   25.4375
# differences len:  13070 differences calls:  22000
# Generation: 20 , Post generation Population: 700
# Generation: 21 , Pre generation Population:  700
#   maxDifference:   51.15625
#   meanDifference:  36.74743052484152
#   minDifference:   25.4375
# differences len:  13923 differences calls:  23400
# Generation: 21 , Post generation Population: 700
# Generation: 22 , Pre generation Population:  700
#   maxDifference:   51.15625
#   meanDifference:  36.80201897974103
#   minDifference:   24.5625
# differences len:  14755 differences calls:  24800
# Generation: 22 , Post generation Population: 700
# Generation: 23 , Pre generation Population:  700
#   maxDifference:   51.15625
#   meanDifference:  36.73891972578507
#   minDifference:   24.5625
# differences len:  15577 differences calls:  26200
# Generation: 23 , Post generation Population: 700
# Generation: 24 , Pre generation Population:  700
#   maxDifference:   51.15625
#   meanDifference:  36.64663335729029
#   minDifference:   24.5625
# differences len:  16390 differences calls:  27600
# Generation: 24 , Post generation Population: 700
# Generation: 25 , Pre generation Population:  700
#   maxDifference:   47.90625
#   meanDifference:  36.48198660714287
#   minDifference:   24.5625
# differences len:  17195 differences calls:  29000
# Generation: 25 , Post generation Population: 700
# Generation: 26 , Pre generation Population:  700
#   maxDifference:   49.53125
#   meanDifference:  36.333618697478975
#   minDifference:   23.5625
# differences len:  18006 differences calls:  30400
# Generation: 26 , Post generation Population: 700
# Generation: 27 , Pre generation Population:  700
#   maxDifference:   51.15625
#   meanDifference:  36.45335086337167
#   minDifference:   23.125
# differences len:  18816 differences calls:  31800
# Generation: 27 , Post generation Population: 700
# Generation: 28 , Pre generation Population:  700
#   maxDifference:   49.53125
#   meanDifference:  36.397006156629296
#   minDifference:   25.25
# differences len:  19652 differences calls:  33200
# Generation: 28 , Post generation Population: 700
# Generation: 29 , Pre generation Population:  700
#   maxDifference:   51.15625
#   meanDifference:  36.27087345354809
#   minDifference:   25.5625
# differences len:  20451 differences calls:  34600
# Generation: 29 , Post generation Population: 700
# Generation: 30 , Pre generation Population:  700
#   maxDifference:   51.15625
#   meanDifference:  36.09749649859945
#   minDifference:   24.4375
# differences len:  21245 differences calls:  36000
# Generation: 30 , Post generation Population: 800
# Generation: 31 , Pre generation Population:  800
#   maxDifference:   51.15625
#   meanDifference:  36.000667253880714
#   minDifference:   24.4375
# differences len:  22177 differences calls:  37600
# Generation: 31 , Post generation Population: 800
# Generation: 32 , Pre generation Population:  800
#   maxDifference:   51.15625
#   meanDifference:  36.134137688929734
#   minDifference:   24.4375
# differences len:  23106 differences calls:  39200
# Generation: 32 , Post generation Population: 800
# Generation: 33 , Pre generation Population:  800
#   maxDifference:   47.875
#   meanDifference:  36.0243212571487
#   minDifference:   24.4375
# differences len:  24034 differences calls:  40800
# Generation: 33 , Post generation Population: 800
# Generation: 34 , Pre generation Population:  800
#   maxDifference:   47.3125
#   meanDifference:  35.794511994216556
#   minDifference:   23.3125
# differences len:  24955 differences calls:  42400
# Generation: 34 , Post generation Population: 800
# Generation: 35 , Pre generation Population:  800
#   maxDifference:   51.15625
#   meanDifference:  35.85098309307276
#   minDifference:   23.3125
# differences len:  25862 differences calls:  44000
# Generation: 35 , Post generation Population: 800
# Generation: 36 , Pre generation Population:  800
#   maxDifference:   51.15625
#   meanDifference:  35.8674245557598
#   minDifference:   23.3125
# differences len:  26752 differences calls:  45600
# Generation: 36 , Post generation Population: 800
# Generation: 37 , Pre generation Population:  800
#   maxDifference:   51.15625
#   meanDifference:  35.82756663602941
#   minDifference:   24.4375
# differences len:  27705 differences calls:  47200
# Generation: 37 , Post generation Population: 800
# Generation: 38 , Pre generation Population:  800
#   maxDifference:   51.15625
#   meanDifference:  35.625457899305545
#   minDifference:   23.1875
# differences len:  28655 differences calls:  48800
# Generation: 38 , Post generation Population: 800
# Generation: 39 , Pre generation Population:  800
#   maxDifference:   49.53125
#   meanDifference:  35.631921083537584
#   minDifference:   23.1875
# differences len:  29590 differences calls:  50400
# Generation: 39 , Post generation Population: 800
# Generation: 40 , Pre generation Population:  800
#   maxDifference:   51.15625
#   meanDifference:  35.555198503880725
#   minDifference:   23.1875
# differences len:  30506 differences calls:  52000
# Generation: 40 , Post generation Population: 900
# Generation: 41 , Pre generation Population:  900
#   maxDifference:   51.15625
#   meanDifference:  35.59197996096587
#   minDifference:   24.1875
# differences len:  31540 differences calls:  53800
# Generation: 41 , Post generation Population: 900
# Generation: 42 , Pre generation Population:  900
#   maxDifference:   51.15625
#   meanDifference:  35.41239106753812
#   minDifference:   24.1875
# differences len:  32564 differences calls:  55600
# Generation: 42 , Post generation Population: 900
# Generation: 43 , Pre generation Population:  900
#   maxDifference:   51.15625
#   meanDifference:  35.240868736383426
#   minDifference:   23.8125
# differences len:  33606 differences calls:  57400
# Generation: 43 , Post generation Population: 900
# Generation: 44 , Pre generation Population:  900
#   maxDifference:   51.15625
#   meanDifference:  35.21169662309368
#   minDifference:   24.0625
# differences len:  34629 differences calls:  59200
# Generation: 44 , Post generation Population: 900
# Generation: 45 , Pre generation Population:  900
#   maxDifference:   51.15625
#   meanDifference:  35.215048225308635
#   minDifference:   22.5
# differences len:  35644 differences calls:  61000
# Generation: 45 , Post generation Population: 900
# Generation: 46 , Pre generation Population:  900
#   maxDifference:   48.1875
#   meanDifference:  35.11577875363108
#   minDifference:   22.9375
# differences len:  36727 differences calls:  62800
# Generation: 46 , Post generation Population: 900
# Generation: 47 , Pre generation Population:  900
#   maxDifference:   51.15625
#   meanDifference:  35.14995132080609
#   minDifference:   22.9375
# differences len:  37742 differences calls:  64600
# Generation: 47 , Post generation Population: 900
# Generation: 48 , Pre generation Population:  900
#   maxDifference:   48.1875
#   meanDifference:  35.12920717592593
#   minDifference:   23.375
# differences len:  38763 differences calls:  66400
# Generation: 48 , Post generation Population: 900
# Generation: 49 , Pre generation Population:  900
#   maxDifference:   48.1875
#   meanDifference:  34.873227691539554
#   minDifference:   23.375
# differences len:  39794 differences calls:  68200
# Generation: 49 , Post generation Population: 900
# Generation: 50 , Pre generation Population:  900
#   maxDifference:   51.15625
#   meanDifference:  34.92430510167031
#   minDifference:   23.375
# differences len:  40804 differences calls:  70000
# Generation: 50 , Post generation Population: 1000
# Generation: 51 , Pre generation Population:  1000
#   maxDifference:   47.84375
#   meanDifference:  34.90570945669933
#   minDifference:   23.375
# differences len:  41934 differences calls:  72000
# Generation: 51 , Post generation Population: 1000
# Generation: 52 , Pre generation Population:  1000
#   maxDifference:   47.0625
#   meanDifference:  34.778685457516346
#   minDifference:   22.4375
# differences len:  43089 differences calls:  74000
# Generation: 52 , Post generation Population: 1000
# Generation: 53 , Pre generation Population:  1000
#   maxDifference:   51.15625
#   meanDifference:  34.75167953431373
#   minDifference:   23.375
# differences len:  44205 differences calls:  76000
# Generation: 53 , Post generation Population: 1000
# Generation: 54 , Pre generation Population:  1000
#   maxDifference:   51.15625
#   meanDifference:  34.80490114379085
#   minDifference:   23.375
# differences len:  45344 differences calls:  78000
# Generation: 54 , Post generation Population: 1000
# Generation: 55 , Pre generation Population:  1000
#   maxDifference:   47.5
#   meanDifference:  34.73396517565359
#   minDifference:   22.1875
# differences len:  46486 differences calls:  80000
# Generation: 55 , Post generation Population: 1000
# Generation: 56 , Pre generation Population:  1000
#   maxDifference:   52.37500000000001
#   meanDifference:  34.6317066993464
#   minDifference:   22.1875
# differences len:  47584 differences calls:  82000
# Generation: 56 , Post generation Population: 1000
# Generation: 57 , Pre generation Population:  1000
#   maxDifference:   46.96875
#   meanDifference:  34.4740498366013
#   minDifference:   22.1875
# differences len:  48729 differences calls:  84000
# Generation: 57 , Post generation Population: 1000
# Generation: 58 , Pre generation Population:  1000
#   maxDifference:   51.15625
#   meanDifference:  34.50881219362746
#   minDifference:   22.1875
# differences len:  49880 differences calls:  86000
# Generation: 58 , Post generation Population: 1000
# Generation: 59 , Pre generation Population:  1000
#   maxDifference:   51.15625
#   meanDifference:  34.48672232434642
#   minDifference:   22.1875
# differences len:  50988 differences calls:  88000
# Generation: 59 , Post generation Population: 1000
# Generation: 60 , Pre generation Population:  1000
#   maxDifference:   47.0625
#   meanDifference:  34.377311989379095
#   minDifference:   22.1875
# differences len:  52140 differences calls:  90000
# Generation: 60 , Post generation Population: 1100
# Generation: 61 , Pre generation Population:  1100
#   maxDifference:   47.0625
#   meanDifference:  34.383168820558524
#   minDifference:   21.8125
# differences len:  53360 differences calls:  92200
# Generation: 61 , Post generation Population: 1100
# Generation: 62 , Pre generation Population:  1100
#   maxDifference:   47.0625
#   meanDifference:  34.19965259209745
#   minDifference:   22.1875
# differences len:  54585 differences calls:  94400
# Generation: 62 , Post generation Population: 1100
# Generation: 63 , Pre generation Population:  1100
#   maxDifference:   46.53125
#   meanDifference:  34.23456346553773
#   minDifference:   20.8125
# differences len:  55822 differences calls:  96600
# Generation: 63 , Post generation Population: 1100
# Generation: 64 , Pre generation Population:  1100
#   maxDifference:   46.65625
#   meanDifference:  34.18755236185383
#   minDifference:   20.8125
# differences len:  57009 differences calls:  98800
# Generation: 64 , Post generation Population: 1100
# Generation: 65 , Pre generation Population:  1100
#   maxDifference:   47.25
#   meanDifference:  34.3075099338978
#   minDifference:   20.8125
# differences len:  58192 differences calls:  101000
# Generation: 65 , Post generation Population: 1100
# Generation: 66 , Pre generation Population:  1100
#   maxDifference:   47.0625
#   meanDifference:  34.108015077243024
#   minDifference:   20.8125
# differences len:  59347 differences calls:  103200
# Generation: 66 , Post generation Population: 1100
# Generation: 67 , Pre generation Population:  1100
#   maxDifference:   46.21875
#   meanDifference:  34.11713967265533
#   minDifference:   20.8125
# differences len:  60551 differences calls:  105400
# Generation: 67 , Post generation Population: 1100
# Generation: 68 , Pre generation Population:  1100
#   maxDifference:   46.125
#   meanDifference:  34.06641032030832
#   minDifference:   20.8125
# differences len:  61714 differences calls:  107600
# Generation: 68 , Post generation Population: 1100
# Generation: 69 , Pre generation Population:  1100
#   maxDifference:   47.26315789473686
#   meanDifference:  33.952430418738466
#   minDifference:   20.8125
# differences len:  62910 differences calls:  109800
# Generation: 69 , Post generation Population: 1100
# Generation: 70 , Pre generation Population:  1100
#   maxDifference:   45.84375
#   meanDifference:  33.892111278223396
#   minDifference:   20.8125
# differences len:  64121 differences calls:  112000
# Generation: 70 , Post generation Population: 1200
# Generation: 71 , Pre generation Population:  1200
#   maxDifference:   45.96875
#   meanDifference:  33.80798143041942
#   minDifference:   19.0625
# differences len:  65384 differences calls:  114400
# Generation: 71 , Post generation Population: 1200
# Generation: 72 , Pre generation Population:  1200
#   maxDifference:   51.15625
#   meanDifference:  33.85980332584425
#   minDifference:   19.0625
# differences len:  66617 differences calls:  116800
# Generation: 72 , Post generation Population: 1200
# Generation: 73 , Pre generation Population:  1200
#   maxDifference:   51.15625
#   meanDifference:  33.81096200980395
#   minDifference:   19.0625
# differences len:  67888 differences calls:  119200
# Generation: 73 , Post generation Population: 1200
# Generation: 74 , Pre generation Population:  1200
#   maxDifference:   51.15625
#   meanDifference:  33.849021395016344
#   minDifference:   19.0625
# differences len:  69135 differences calls:  121600
# Generation: 74 , Post generation Population: 1200
# Generation: 75 , Pre generation Population:  1200
#   maxDifference:   45.875
#   meanDifference:  33.77330278118194
#   minDifference:   19.0625
# differences len:  70420 differences calls:  124000
# Generation: 75 , Post generation Population: 1200
# Generation: 76 , Pre generation Population:  1200
#   maxDifference:   46.03125
#   meanDifference:  33.66498970247823
#   minDifference:   19.0625
# differences len:  71697 differences calls:  126400
# Generation: 76 , Post generation Population: 1200
# Generation: 77 , Pre generation Population:  1200
#   maxDifference:   46.03125
#   meanDifference:  33.49801708877997
#   minDifference:   19.0625
# differences len:  72946 differences calls:  128800
# Generation: 77 , Post generation Population: 1200
# Generation: 78 , Pre generation Population:  1200
#   maxDifference:   46.9375
#   meanDifference:  33.42381689133988
#   minDifference:   19.0625
# differences len:  74169 differences calls:  131200
# Generation: 78 , Post generation Population: 1200
# Generation: 79 , Pre generation Population:  1200
#   maxDifference:   44.38888888888889
#   meanDifference:  33.30171389910129
#   minDifference:   19.0625
# differences len:  75442 differences calls:  133600
# Generation: 79 , Post generation Population: 1200
# Generation: 80 , Pre generation Population:  1200
#   maxDifference:   45.0625
#   meanDifference:  33.193913568899795
#   minDifference:   19.0625
# differences len:  76685 differences calls:  136000
# Generation: 80 , Post generation Population: 1300
# Generation: 81 , Pre generation Population:  1300
#   maxDifference:   45.59375
#   meanDifference:  33.07914168552036
#   minDifference:   17.5625
# differences len:  77997 differences calls:  138600
# Generation: 81 , Post generation Population: 1300
# Generation: 82 , Pre generation Population:  1300
#   maxDifference:   45.59375
#   meanDifference:  32.95563914027148
#   minDifference:   17.5625
# differences len:  79350 differences calls:  141200
# Generation: 82 , Post generation Population: 1300
# Generation: 83 , Pre generation Population:  1300
#   maxDifference:   44.0625
#   meanDifference:  32.80106704059828
#   minDifference:   17.5625
# differences len:  80663 differences calls:  143800
# Generation: 83 , Post generation Population: 1300
# Generation: 84 , Pre generation Population:  1300
#   maxDifference:   42.4375
#   meanDifference:  32.840565846530914
#   minDifference:   17.5625
# differences len:  81956 differences calls:  146400
# Generation: 84 , Post generation Population: 1300
# Generation: 85 , Pre generation Population:  1300
#   maxDifference:   43.40625
#   meanDifference:  32.67361338926596
#   minDifference:   17.5625
# differences len:  83244 differences calls:  149000
# Generation: 85 , Post generation Population: 1300
# Generation: 86 , Pre generation Population:  1300
#   maxDifference:   43.40625
#   meanDifference:  32.47169172637003
#   minDifference:   17.3125
# differences len:  84530 differences calls:  151600
# Generation: 86 , Post generation Population: 1300
# Generation: 87 , Pre generation Population:  1300
#   maxDifference:   44.78947368421053
#   meanDifference:  32.36752358779208
#   minDifference:   17.3125
# differences len:  85794 differences calls:  154200
# Generation: 87 , Post generation Population: 1300
# Generation: 88 , Pre generation Population:  1300
#   maxDifference:   43.05555555555554
#   meanDifference:  32.21337921065863
#   minDifference:   17.3125
# differences len:  87081 differences calls:  156800
# Generation: 88 , Post generation Population: 1300
# Generation: 89 , Pre generation Population:  1300
#   maxDifference:   43.96875
#   meanDifference:  32.05050512192056
#   minDifference:   17.3125
# differences len:  88363 differences calls:  159400
# Generation: 89 , Post generation Population: 1300
# Generation: 90 , Pre generation Population:  1300
#   maxDifference:   44.03125
#   meanDifference:  31.96282428355958
#   minDifference:   17.3125
# differences len:  89584 differences calls:  162000
# Generation: 90 , Post generation Population: 1400
# Generation: 91 , Pre generation Population:  1400
#   maxDifference:   42.83333333333334
#   meanDifference:  31.841764851774045
#   minDifference:   17.3125
# differences len:  90945 differences calls:  164800
# Generation: 91 , Post generation Population: 1400
# Generation: 92 , Pre generation Population:  1400
#   maxDifference:   44.6875
#   meanDifference:  31.727761510854346
#   minDifference:   17.3125
# differences len:  92258 differences calls:  167600
# Generation: 92 , Post generation Population: 1400
# Generation: 93 , Pre generation Population:  1400
#   maxDifference:   44.6875
#   meanDifference:  31.573771519024277
#   minDifference:   17.3125
# differences len:  93571 differences calls:  170400
# Generation: 93 , Post generation Population: 1400
# Generation: 94 , Pre generation Population:  1400
#   maxDifference:   43.0
#   meanDifference:  31.18421196603642
#   minDifference:   17.3125
# differences len:  94821 differences calls:  173200
# Generation: 94 , Post generation Population: 1400
# Generation: 95 , Pre generation Population:  1400
#   maxDifference:   41.94444444444446
#   meanDifference:  30.83165667308589
#   minDifference:   17.3125
# differences len:  96023 differences calls:  176000
# Generation: 95 , Post generation Population: 1400
# Generation: 96 , Pre generation Population:  1400
#   maxDifference:   41.3888888888889
#   meanDifference:  30.40692577030814
#   minDifference:   17.3125
# differences len:  97251 differences calls:  178800
# Generation: 96 , Post generation Population: 1400
# Generation: 97 , Pre generation Population:  1400
#   maxDifference:   43.3888888888889
#   meanDifference:  30.064994674953326
#   minDifference:   17.3125
# differences len:  98439 differences calls:  181600
# Generation: 97 , Post generation Population: 1400
# Generation: 98 , Pre generation Population:  1400
#   maxDifference:   43.5
#   meanDifference:  29.634850315126055
#   minDifference:   15.9375
# differences len:  99599 differences calls:  184400
# Generation: 98 , Post generation Population: 1400
# Generation: 99 , Pre generation Population:  1400
#   maxDifference:   42.5625
#   meanDifference:  29.158903696895422
#   minDifference:   15.9375
# differences len:  100738 differences calls:  187200
# Generation: 99 , Post generation Population: 1400
# Generation: 100 , Pre generation Population:  1400
#   maxDifference:   42.5625
#   meanDifference:  28.764056445494866
#   minDifference:   15.9375
# differences len:  101841 differences calls:  190000
# Generation: 100 , Post generation Population: 1500
